# %% [markdown]
# <a href="https://colab.research.google.com/github/krutydm-sketch/business_forecasting/blob/main/TabPFN_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mlforecast utilsforecast coreforecast holidays lightgbm tabpfn
# Out:
# Collecting mlforecast
#   Downloading mlforecast-1.0.31-py3-none-any.whl.metadata (10 kB)
# Collecting utilsforecast
#   Downloading utilsforecast-0.2.16-py3-none-any.whl.metadata (4.7 kB)
# Collecting coreforecast
#   Downloading coreforecast-0.0.17-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: holidays in /usr/local/lib/python3.12/dist-packages (0.95)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Collecting tabpfn
#   Downloading tabpfn-8.0.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from mlforecast) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from mlforecast) (2025.3.0)
# Requirement already satisfied: narwhals in /usr/local/lib/python3.12/dist-packages (from mlforecast) (2.20.0)
# Collecting optuna (from mlforecast)
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas<3.0 in /usr/local/lib/python3.12/dist-packages (from mlforecast) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mlforecast) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from utilsforecast) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from utilsforecast) (26.1)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)
# Requirement already satisfied: torch>=2.5 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.10.0+cu128)
# Requirement already satisfied: typing_extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: einops>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.11.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.14.0)
# Collecting eval-type-backport>=0.2.2 (from tabpfn)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.5.3)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.67.3)
# Collecting tabpfn-common-utils>=0.2.13 (from tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading tabpfn_common_utils-0.2.21-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (6.0.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (0.24.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0->mlforecast) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0->mlforecast) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.10.1->tabpfn) (1.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mlforecast) (3.6.0)
# Requirement already satisfied: nvidia-ml-py>=13.590.48 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (13.595.45)
# Requirement already satisfied: platformdirs>=4 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (4.9.6)
# Collecting posthog>=6.7 (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading posthog-7.14.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests>=2.32.5 (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading requests-2.34.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.5->tabpfn) (1.5.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->mlforecast) (1.18.4)
# Collecting colorlog (from optuna->mlforecast)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->mlforecast) (2.0.49)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->mlforecast) (1.3.11)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (0.16.0)
# Collecting backoff>=1.10.0 (from posthog>=6.7->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=6.7->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->mlforecast) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5->tabpfn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.5->tabpfn) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->tabpfn) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->tabpfn) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->tabpfn) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->tabpfn) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->tabpfn) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->tabpfn) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.23.0->tabpfn) (0.1.2)
# Downloading mlforecast-1.0.31-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.1/128.1 kB 7.8 MB/s eta 0:00:00
# Downloading utilsforecast-0.2.16-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 4.8 MB/s eta 0:00:00
# Downloading coreforecast-0.0.17-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.2/348.2 kB 21.0 MB/s eta 0:00:00
# Downloading tabpfn-8.0.1-py3-none-any.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.5/722.5 kB 45.2 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading tabpfn_common_utils-0.2.21-py3-none-any.whl (39 kB)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 42.1 MB/s eta 0:00:00
# Downloading posthog-7.14.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.2/240.2 kB 28.2 MB/s eta 0:00:00
# Downloading requests-2.34.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 kB 9.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: requests, eval-type-backport, coreforecast, colorlog, backoff, posthog, utilsforecast, tabpfn-common-utils, optuna, mlforecast, tabpfn
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.0 which is incompatible.
# Successfully installed backoff-2.2.1 colorlog-6.10.1 coreforecast-0.0.17 eval-type-backport-0.3.1 mlforecast-1.0.31 optuna-4.8.0 posthog-7.14.1 requests-2.34.0 tabpfn-8.0.1 tabpfn-common-utils-0.2.21 utilsforecast-0.2.16

# %%
import os
import holidays
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
from mlforecast import MLForecast
from mlforecast.lag_transforms import RollingMean
from tabpfn import TabPFNRegressor
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import bias, mae, rmse, mape

# %%
us_holidays = holidays.US(years=range(2021, 2024))

df_tab = (
    pd.read_parquet("sample_hotels-1.parquet")
    .query("unique_id not in ['hotel_77', 'hotel_28']")
    .drop(columns=["target_month", "target_year", "location_type"])
    .assign(
        ds=lambda x: pd.to_datetime(x["ds"]),
        unique_id=lambda x: x["unique_id"].astype(str),
        y=lambda x: x["y"].astype(float),

        hotel_type=lambda x: x["hotel_type"].astype("category"),

        holiday_name=lambda x: (
            x["ds"].dt.date.apply(lambda d: us_holidays.get(d))
            .astype("category")
            .cat.add_categories("None")
            .fillna("None")
        ),

        day_of_week=lambda x: x["ds"].dt.day_name().astype("category")
    )
    .drop(columns=["holiday_flag", "target_day"])
)

df_tab = pd.get_dummies(
    df_tab,
    columns=["day_of_week", "holiday_name", "hotel_type"],
    drop_first=True,
    )

df_tab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9282 entries, 1430 to 298041
# Data columns (total 86 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   unique_id                                                     9282 non-null   object
#  1   ds                                                            9282 non-null   datetime64[us]
#  2   y                                                             9282 non-null   float64
#  3   otb_1                                                         9282 non-null   float64
#  4   otb_2                                                         9282 non-null   float64
#  5   otb_3                                                         9282 non-null   float64
#  6   otb_4                                                         9282 non-null   float64
#  7   otb_5                                                         9282 non-null   float64
#  8   otb_6                                                         9282 non-null   float64
#  9   otb_7                                                         9282 non-null   float64
#  10  otb_8                                                         9282 non-null   float64
#  11  otb_9                                                         9282 non-null   float64
#  12  otb_10                                                        9282 non-null   float64
#  13  otb_11                                                        9282 non-null   float64
#  14  otb_12                                                        9282 non-null   float64
#  15  otb_13                                                        9282 non-null   float64
#  16  otb_14                                                        9282 non-null   float64
#  17  otb_15                                                        9282 non-null   float64
#  18  otb_16                                                        9282 non-null   float64
#  19  otb_17                                                        9282 non-null   float64
#  20  otb_18                                                        9282 non-null   float64
#  21  otb_19                                                        9282 non-null   float64
#  22  otb_20                                                        9282 non-null   float64
#  23  otb_21                                                        9282 non-null   float64
#  24  otb_22                                                        9282 non-null   float64
#  25  otb_23                                                        9282 non-null   float64
#  26  otb_24                                                        9282 non-null   float64
#  27  otb_25                                                        9282 non-null   float64
#  28  otb_26                                                        9282 non-null   float64
#  29  otb_27                                                        9282 non-null   float64
#  30  otb_28                                                        9282 non-null   float64
#  31  otb_29                                                        9282 non-null   float64
#  32  otb_30                                                        9282 non-null   float64
#  33  otb_31                                                        9282 non-null   float64
#  34  otb_32                                                        9282 non-null   float64
#  35  otb_33                                                        9282 non-null   float64
#  36  otb_34                                                        9282 non-null   float64
#  37  otb_35                                                        9282 non-null   float64
#  38  otb_36                                                        9282 non-null   float64
#  39  otb_37                                                        9282 non-null   float64
#  40  otb_38                                                        9282 non-null   float64
#  41  otb_39                                                        9282 non-null   float64
#  42  otb_40                                                        9282 non-null   float64
#  43  otb_41                                                        9282 non-null   float64
#  44  otb_42                                                        9282 non-null   float64
#  45  otb_43                                                        9282 non-null   float64
#  46  otb_44                                                        9282 non-null   float64
#  47  otb_45                                                        9282 non-null   float64
#  48  otb_46                                                        9282 non-null   float64
#  49  otb_47                                                        9282 non-null   float64
#  50  otb_48                                                        9282 non-null   float64
#  51  otb_49                                                        9282 non-null   float64
#  52  otb_50                                                        9282 non-null   float64
#  53  otb_51                                                        9282 non-null   float64
#  54  otb_52                                                        9282 non-null   float64
#  55  otb_53                                                        9282 non-null   float64
#  56  otb_54                                                        9282 non-null   float64
#  57  otb_55                                                        9282 non-null   float64
#  58  otb_56                                                        9282 non-null   float64
#  59  otb_57                                                        9282 non-null   float64
#  60  otb_58                                                        9282 non-null   float64
#  61  otb_59                                                        9282 non-null   float64
#  62  otb_60                                                        9282 non-null   float64
#  63  day_of_week_Monday                                            9282 non-null   bool
#  64  day_of_week_Saturday                                          9282 non-null   bool
#  65  day_of_week_Sunday                                            9282 non-null   bool
#  66  day_of_week_Thursday                                          9282 non-null   bool
#  67  day_of_week_Tuesday                                           9282 non-null   bool
#  68  day_of_week_Wednesday                                         9282 non-null   bool
#  69  holiday_name_Christmas Day (observed)                         9282 non-null   bool
#  70  holiday_name_Columbus Day                                     9282 non-null   bool
#  71  holiday_name_Independence Day                                 9282 non-null   bool
#  72  holiday_name_Juneteenth National Independence Day             9282 non-null   bool
#  73  holiday_name_Juneteenth National Independence Day (observed)  9282 non-null   bool
#  74  holiday_name_Labor Day                                        9282 non-null   bool
#  75  holiday_name_Martin Luther King Jr. Day                       9282 non-null   bool
#  76  holiday_name_Memorial Day                                     9282 non-null   bool
#  77  holiday_name_New Year's Day                                   9282 non-null   bool
#  78  holiday_name_New Year's Day (observed)                        9282 non-null   bool
#  79  holiday_name_Thanksgiving Day                                 9282 non-null   bool
#  80  holiday_name_Veterans Day                                     9282 non-null   bool
#  81  holiday_name_Washington's Birthday                            9282 non-null   bool
#  82  holiday_name_None                                             9282 non-null   bool
#  83  hotel_type_Key Central Business District                      9282 non-null   bool
#  84  hotel_type_Other High Leisure Mix                             9282 non-null   bool
#  85  hotel_type_Resorts & Destinations                             9282 non-null   bool
# dtypes: bool(23), datetime64[us](1), float64(61), object(1)
# memory usage: 4.7+ MB

# %%
import torch
print(f"Is CUDA available? {torch.cuda.is_available()}")
print(f"Device Name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# Is CUDA available? True
# Device Name: Tesla T4

# %%
from google.colab import userdata
os.environ["TABPFN_TOKEN"] = userdata.get("TABPFN_TOKEN")
ml_models = {
    "TabPFN": TabPFNRegressor(device='cuda')
}

ml = MLForecast(
    models=ml_models,
    freq="D",
    lags=list(range(28, 57)) + [60, 90, 365],
    lag_transforms={
        28: [
            RollingMean(window_size=7),
            RollingMean(window_size=14),
        ]
    },
    date_features=["year", "month"],
)

cross_ml = ml.cross_validation(
    df=df_tab,
    n_windows=6,
    h=28,
    step_size=28,
    static_features=[],
)

# %%
eval_ml = evaluate(
    df= cross_ml,
    metrics= [bias, mae, rmse, mape],
    models=["TabPFN"],
    target_col='y'
)

eval_summary = eval_ml.drop(columns=['cutoff']).groupby(['unique_id','metric']).mean().reset_index(inplace=False)
print(eval_summary)
# Out:
#     unique_id metric    TabPFN
# 0     hotel_0   bias -0.009596
# 1     hotel_0    mae  0.057361
# 2     hotel_0   mape  0.081867
# 3     hotel_0   rmse  0.073448
# 4   hotel_105   bias -0.021749
# ..        ...    ...       ...
# 63   hotel_91   rmse  0.076595
# 64   hotel_98   bias  0.003833
# 65   hotel_98    mae  0.028199
# 66   hotel_98   mape  0.140318
# 67   hotel_98   rmse  0.035873
#
# [68 rows x 3 columns]

# %%
eval_final_summary = (
    eval_summary
    .drop(columns='unique_id')
    .groupby('metric')
    .mean()
    .reset_index()
)
print(eval_final_summary)
# Out:
#   metric    TabPFN
# 0   bias -0.001872
# 1    mae  0.041332
# 2   mape  0.198136
# 3   rmse  0.053801

# %%
import json

notebook_path = "/content/TABPFN_Final.ipynb"

with open(notebook_path, "r", encoding="utf-8") as f:
    nb = json.load(f)

nb.get("metadata", {}).pop("widgets", None)

for cell in nb.get("cells", []):
    cell.get("metadata", {}).get("colab", {}).pop("referenced_widgets", None)

for cell in nb.get("cells", []):
    if cell.get("cell_type") == "code":
        cell["outputs"] = []
        cell["execution_count"] = None

fixed_path = "/content/fixed_notebook.ipynb"

with open(fixed_path, "w", encoding="utf-8") as f:
    json.dump(nb, f, indent=1)

print(f"Saved fixed notebook as: {fixed_path}")
# Out:
# Saved fixed notebook as: /content/fixed_notebook.ipynb
